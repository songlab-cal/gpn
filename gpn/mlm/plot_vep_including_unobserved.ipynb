# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import tqdm

# %%
df = pd.read_parquet("results/vep/example_annotated.parquet/results_512_convnet_only_athaliana_lower_lr_v2_checkpoint-80000_/results.parquet")
df
# Out:
#        chromosome      pos ID ref alt QUAL FILTER  \
# 0            Chr5  3500000  .   A   C    .      .
# 1            Chr5  3500000  .   A   G    .      .
# 2            Chr5  3500000  .   A   T    .      .
# 3            Chr5  3500001  .   C   A    .      .
# 4            Chr5  3500001  .   C   G    .      .
# ...           ...      ... ..  ..  ..  ...    ...
# 299995       Chr5  3599998  .   T   C    .      .
# 299996       Chr5  3599998  .   T   G    .      .
# 299997       Chr5  3599999  .   T   A    .      .
# 299998       Chr5  3599999  .   T   C    .      .
# 299999       Chr5  3599999  .   T   G    .      .
#
#                                                      INFO  model_llr
# 0       CSQ=C|upstream_gene_variant|MODIFIER|ALF4|AT5G...  -1.171289
# 1       CSQ=G|upstream_gene_variant|MODIFIER|ALF4|AT5G...  -0.214262
# 2       CSQ=T|upstream_gene_variant|MODIFIER|ALF4|AT5G...  -0.242087
# 3       CSQ=A|upstream_gene_variant|MODIFIER|ALF4|AT5G...   0.965767
# 4       CSQ=G|upstream_gene_variant|MODIFIER|ALF4|AT5G...   0.651589
# ...                                                   ...        ...
# 299995  CSQ=C|upstream_gene_variant|MODIFIER|HY5|AT5G1...   0.086468
# 299996  CSQ=G|upstream_gene_variant|MODIFIER|HY5|AT5G1...   0.435724
# 299997  CSQ=A|upstream_gene_variant|MODIFIER|HY5|AT5G1...  -0.022641
# 299998  CSQ=C|upstream_gene_variant|MODIFIER|HY5|AT5G1...  -0.543526
# 299999  CSQ=G|upstream_gene_variant|MODIFIER|HY5|AT5G1...   0.301313
#
# [300000 rows x 9 columns]

# %%
df["consequence"] = df.INFO.str.replace("CSQ=", "").str.split(",").apply(lambda x: ",".join(sorted(list(set([y.split("|")[1] for y in x])))))
df.consequence.value_counts()[:20]
# Out:
# downstream_gene_variant,upstream_gene_variant                                    80838
# downstream_gene_variant,missense_variant,upstream_gene_variant                   27315
# downstream_gene_variant,missense_variant                                         24706
# downstream_gene_variant,intron_variant,upstream_gene_variant                     21435
# downstream_gene_variant,intron_variant                                           16833
# upstream_gene_variant                                                            15186
# downstream_gene_variant                                                          14106
# 5_prime_UTR_variant,downstream_gene_variant,upstream_gene_variant                 8481
# downstream_gene_variant,synonymous_variant,upstream_gene_variant                  8270
# 3_prime_UTR_variant,downstream_gene_variant                                       7662
# downstream_gene_variant,synonymous_variant                                        7286
# missense_variant,upstream_gene_variant                                            6534
# 3_prime_UTR_variant,downstream_gene_variant,upstream_gene_variant                 6111
# non_coding_transcript_exon_variant,upstream_gene_variant                          5742
# 3_prime_UTR_variant,upstream_gene_variant                                         4542
# intron_variant,upstream_gene_variant                                              3693
# downstream_gene_variant,intron_variant,missense_variant,upstream_gene_variant     3678
# intron_variant&non_coding_transcript_variant,upstream_gene_variant                2583
# synonymous_variant,upstream_gene_variant                                          2141
# 5_prime_UTR_variant,downstream_gene_variant                                       1824
# Name: consequence, dtype: int64

# %%
df.consequence = df.consequence.str.replace("downstream_gene_variant,", "").astype(str)
df.consequence = df.consequence.str.replace(",downstream_gene_variant", "").astype(str)
df.consequence = df.consequence.str.replace("upstream_gene_variant,", "").astype(str)
df.consequence = df.consequence.str.replace(",upstream_gene_variant", "").astype(str)
df.consequence.value_counts()[:20]
# Out:
# upstream_gene_variant                                                       96024
# missense_variant                                                            59807
# intron_variant                                                              42270
# 3_prime_UTR_variant                                                         18315
# synonymous_variant                                                          18078
# downstream_gene_variant                                                     14106
# 5_prime_UTR_variant                                                         12537
# non_coding_transcript_exon_variant                                           6417
# intron_variant,missense_variant                                              4309
# stop_gained                                                                  3637
# 5_prime_UTR_variant,intron_variant                                           2670
# intron_variant&non_coding_transcript_variant                                 2583
# splice_polypyrimidine_tract_variant&intron_variant                           2484
# 5_prime_UTR_variant,missense_variant                                         1693
# splice_polypyrimidine_tract_variant&splice_region_variant&intron_variant     1656
# 3_prime_UTR_variant,missense_variant                                         1350
# intron_variant,synonymous_variant                                            1239
# missense_variant&splice_region_variant                                       1106
# 3_prime_UTR_variant,intron_variant                                           1014
# splice_donor_region_variant&intron_variant                                    810
# Name: consequence, dtype: int64

# %%
df.consequence.value_counts()
# Out:
# upstream_gene_variant                                                                   96024
# missense_variant                                                                        59807
# intron_variant                                                                          42270
# 3_prime_UTR_variant                                                                     18315
# synonymous_variant                                                                      18078
#                                                                                         ...
# missense_variant&splice_region_variant,stop_gained                                          1
# intron_variant,stop_gained,stop_gained&splice_region_variant                                1
# intron_variant,splice_donor_variant,synonymous_variant                                      1
# 3_prime_UTR_variant,stop_gained,stop_lost                                                   1
# splice_polypyrimidine_tract_variant&splice_region_variant&intron_variant,stop_gained        1
# Name: consequence, Length: 168, dtype: int64

# %%
df[~df.consequence.str.contains(",")].consequence.value_counts()
# Out:
# upstream_gene_variant                                                                                     96024
# missense_variant                                                                                          59807
# intron_variant                                                                                            42270
# 3_prime_UTR_variant                                                                                       18315
# synonymous_variant                                                                                        18078
# downstream_gene_variant                                                                                   14106
# 5_prime_UTR_variant                                                                                       12537
# non_coding_transcript_exon_variant                                                                         6417
# stop_gained                                                                                                3637
# intron_variant&non_coding_transcript_variant                                                               2583
# splice_polypyrimidine_tract_variant&intron_variant                                                         2484
# splice_polypyrimidine_tract_variant&splice_region_variant&intron_variant                                   1656
# missense_variant&splice_region_variant                                                                     1106
# splice_donor_region_variant&intron_variant                                                                  810
# splice_acceptor_variant                                                                                     552
# splice_region_variant&intron_variant                                                                        540
# splice_donor_variant                                                                                        540
# splice_region_variant&synonymous_variant                                                                    327
# splice_donor_5th_base_variant&intron_variant                                                                270
# splice_polypyrimidine_tract_variant&intron_variant&non_coding_transcript_variant                            270
# start_lost                                                                                                  180
# splice_region_variant&non_coding_transcript_exon_variant                                                    180
# splice_polypyrimidine_tract_variant&splice_region_variant&intron_variant&non_coding_transcript_variant      180
# stop_lost                                                                                                   138
# splice_donor_region_variant&intron_variant&non_coding_transcript_variant                                     90
# splice_region_variant&5_prime_UTR_variant                                                                    81
# stop_gained&splice_region_variant                                                                            70
# splice_donor_variant&non_coding_transcript_variant                                                           60
# splice_region_variant&intron_variant&non_coding_transcript_variant                                           60
# splice_acceptor_variant&non_coding_transcript_variant                                                        60
# splice_donor_5th_base_variant&intron_variant&non_coding_transcript_variant                                   30
# stop_retained_variant                                                                                        24
# Name: consequence, dtype: int64

# %%
df[df.consequence.str.contains("start")].consequence.value_counts()
# Out:
# start_lost                                                           180
# missense_variant,start_lost                                           36
# intron_variant,start_lost                                             18
# 5_prime_UTR_variant,missense_variant,start_lost                       17
# 5_prime_UTR_variant,start_lost                                         9
# 5_prime_UTR_variant,non_coding_transcript_exon_variant,start_lost      9
# 5_prime_UTR_variant,start_lost,synonymous_variant                      1
# Name: consequence, dtype: int64

# %%
df[df.consequence.str.contains("inter")].consequence.value_counts()
# Out:
# Series([], Name: consequence, dtype: int64)

# %%
df.consequence.replace("non_coding_transcript_exon_variant", "nc_transcript_exon_variant", inplace=True)

# %%
consequences_to_plot = [
    "start_lost",
    "missense_variant",
    "synonymous_variant",
    "stop_gained",
    #"stop_lost",
    "intron_variant",
    "upstream_gene_variant",
    "downstream_gene_variant",
    "splice_acceptor_variant",
    "splice_donor_variant",
    "3_prime_UTR_variant",
    "5_prime_UTR_variant",
    "nc_transcript_exon_variant",
    #"splice_polypyrimidine_tract_variant&intron_variant",
    #"splice_region_variant&intron_variant",
]

# %%
consequences_to_plot = df.groupby("consequence").model_llr.mean()[consequences_to_plot].sort_values().index.values

# %%
plt.figure(figsize=(8, 8))
g = sns.ecdfplot(
    data=df[df.consequence.isin(consequences_to_plot)],
    hue="consequence",
    hue_order=consequences_to_plot,
    x="model_llr",
    palette="tab20"
)
sns.move_legend(g, "upper right", bbox_to_anchor=(1.55, 1), ncol=1, title_fontsize=14)

# %%
plt.figure(figsize=(8, 8))
g = sns.ecdfplot(
    data=df[df.consequence.isin(consequences_to_plot)],
    hue="consequence",
    hue_order=consequences_to_plot,
    x="model_llr",
    palette="tab20"
)
plt.xlim([-6, -1])
plt.ylim([0, 0.2])
sns.move_legend(g, "upper right", bbox_to_anchor=(1.55, 1), ncol=1, title_fontsize=14)

# %%
plt.figure(figsize=(2.1,4))
sns.barplot(
    data=df[df.consequence.isin(consequences_to_plot)],
    y="consequence",
    x="model_llr",
    color="C0",
    order=consequences_to_plot,
    ci=None,
    #ci="sd",
    #palette="tab20"
);
plt.xlabel("Mean GPN score")
plt.ylabel("")
#plt.savefig("scores_by_consequence.svg", bbox_inches="tight")
# Out:
# Text(0, 0.5, '')

# %%
sns.histplot(
    data=df,
    x="model_llr"
)
plt.axvline(0, linestyle="--", color="black")

# %%
hist_consequences = [
    #"start_lost",
    "stop_gained",
    "missense_variant",
    "synonymous_variant",
    #"stop_lost",
    #"intron_variant",
    #"upstream_gene_variant",
    #"downstream_gene_variant",
    #"splice_acceptor_variant",
    #"splice_donor_variant",
    #"3_prime_UTR_variant",
    #"5_prime_UTR_variant",
    #"nc_transcript_exon_variant",
]
plt.figure(figsize=(4,4))
g = sns.ecdfplot(
    data=df[df.consequence.isin(hist_consequences)],
    x="model_llr",
    hue="consequence",
    hue_order=hist_consequences,
)
sns.move_legend(g, "upper left", bbox_to_anchor=(1, 1))

# %%
g = sns.displot(
    data=df[df.consequence.isin(hist_consequences)],
    x="model_llr",
    row="consequence",
    row_order=hist_consequences,
    kind="hist",
    #stat="density",
    facet_kws=dict(sharey=False),
    height=3.0,
    aspect=1.0,
    bins=50,
)
g.refline(x=0, color="black")
g.set_titles(row_template="{row_name}")
plt.xlabel("GPN score")
plt.savefig("scores_by_consequence_hist.pdf", bbox_inches="tight")
